# %%
print("Data" ,"Science" ,"Mentorship", "Program",sep='-',end='-')
print("By" ,"CampusX",sep='-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %%
cel = input("Enter the celcius degree")
f = int(cel)*(9/5)+32
print(f)
# Out:
# Enter the celcius degree 20
# 68.0

# %%
a = int(input("Enter the frist numbner ")) 
b = int(input("Enter the second number "))
c = a+b
a = c-a
b = c-b
print("After Swap a and b is ",a,b)
# Out:
# Enter the frist numbner  10
# Enter the second number  20
# After Swap a and b is  20 10
