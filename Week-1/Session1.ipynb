# %%
print('hello',2.3,True,sep='/') #sep is seprator
# Out:
# hello/2.3/True

# %%
print('hello',2.3,True,sep='?') #sep is seprator
# Out:
# hello?2.3?True

# %%
print('hello',end='-')
print('world',end='_')
print('Anshul')
# Out:
# hello-world_Anshul

# %%
print(7)
# Out:
# 7

# %%
print(1.2)
# Out:
# 1.2

# %%
print(True)
# Out:
# True

# %%
# 2 DATA TYPES

# %%
#INTEGER
print(8)
#1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
#Decimel 
print(8.4)
print(1.7e309)
# Out:
# 8.4
# inf

# %%
#Bloean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/string
print("Hello World")
# Out:
# Hello World

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
# list-> C-> Array
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Tuple
print((1,2,3,4,5,6))
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# sets 
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictonary
d={"hello":"hi"}
print(d)
type(d)
# Out:
# {'hello': 'hi'}
# dict

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# C/C++
name = 'jayant'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# jayant
# 11

# %%
# Dynamic Typing
a = 5
# Static Typing
#int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'jayant'
print(a)

# Static Binding
#int a = 5
# Out:
# 5
# jayant

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %%
# KEYWOARD AND IDENTIFYER

# %%
# Identifiers
# You can't start with a digit
name1 = 'Jayant'
print(name1)
# You can use special chars -> _
_ = 'jayant'
print(_)
# identiers can not be keyword
# Out:
# Jayant
# jayant

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Email jayntkumar62061@gmail.com
# 'jayntkumar62061@gmail.com'

# %%
# take input from users and store them in a variable
fnum = input("Enter the frist numbner ") #its take by default string because in py str universal
snum = input("Enter the second number ")
print(type(fnum),type(snum))
# add the two number 
result = fnum + snum
#print the result 
print(result)
# Out:
# Enter the frist numbner  10
# Enter the second number  20
# <class 'str'> <class 'str'>
# 1020

# %%
# take input from users and store them in a variable
fnum = input("Enter the frist numbner ") 
snum = input("Enter the second number ")
print(type(fnum),type(snum))
# add the two number 
result = int(fnum) + int(snum)
#print the result 
print(result)
# Out:
# Enter the frist numbner  10
# Enter the second number  20
# <class 'str'> <class 'str'>
# 30

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 5
#       2 print(5+5.6)
#       3 print(type(5),type(5.6))
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %%
# Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923\U0001F47D"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣👽
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership
